# %% [markdown]
# Data Pre - Processing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('datasets/cricket.csv')

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0    4s  6s
# 0   58.6   29  13  7  626+   6
# 1  91.76    4   7  1   141  23
# 2  55.68    5   4  2   186   5
# 3  54.48    7  11  1  246+  11
# 4     56   10   5  2  104+   1

# %%
df.describe()
# Out:
#               Mat        Inns         NO          Runs        Ave        100  \
# count   62.000000   62.000000  62.000000     62.000000  62.000000  62.000000
# mean    80.016129  135.516129  14.080645   6417.483871  53.705000  19.306452
# std     50.785144   86.415076  11.140383   4011.017743   7.183066  12.318969
# min     12.000000   20.000000   1.000000    990.000000  48.000000   1.000000
# 25%     30.250000   51.500000   5.250000   2379.000000  49.510000   7.250000
# 50%     79.000000  134.500000  12.000000   6520.500000  51.940000  19.500000
# 75%    117.750000  196.250000  19.000000   8844.000000  56.345000  29.000000
# max    200.000000  329.000000  49.000000  15921.000000  99.940000  51.000000
#
#               50          0
# count  62.000000  62.000000
# mean   28.580645   7.806452
# std    18.615654   5.536285
# min     3.000000   1.000000
# 25%    11.500000   3.000000
# 50%    28.500000   7.000000
# 75%    42.250000  12.000000
# max    68.000000  22.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  62 non-null     object
#  1   Span    62 non-null     object
#  2   Mat     62 non-null     int64
#  3   Inns    62 non-null     int64
#  4   NO      62 non-null     int64
#  5   Runs    62 non-null     int64
#  6   HS      62 non-null     object
#  7   Ave     62 non-null     float64
#  8   BF      62 non-null     object
#  9   SR      62 non-null     object
#  10  100     62 non-null     int64
#  11  50      62 non-null     int64
#  12  0       62 non-null     int64
#  13  4s      62 non-null     object
#  14  6s      62 non-null     object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 7.4+ KB

# %%
df.shape
# Out:
# (62, 15)

# %% [markdown]
# Univariate Analysis

# %%
df['Span'].value_counts().plot(kind = 'bar',color = 'green')
plt.title('Value count of span')
plt.xlabel('Span')
plt.ylabel('Count')
plt.show()

# %%
df['Mat'].hist(bins=20,color = 'blue',edgecolor = 'black')
plt.title('Matches')
plt.xlabel('Values')
plt.ylabel('Freequency')
plt.show()

# %%
df['Inns'].hist(bins=20,color = 'blue',edgecolor = 'black')
plt.title('Innings')
plt.xlabel('Values')
plt.ylabel('Freequency')
plt.show()

# %%
df['NO'].hist(bins=20,color = 'blue',edgecolor = 'black')
plt.title('NO')
plt.xlabel('Values')
plt.ylabel('Freequency')
plt.show()

# %%
df['Runs'].hist(bins=20,color = 'blue',edgecolor = 'black')
plt.title('Runs')
plt.xlabel('Values')
plt.ylabel('Freequency')
plt.show()

# %%
df['100'].hist(bins=20,color = 'blue',edgecolor = 'black')
plt.title('100s')
plt.xlabel('Values')
plt.ylabel('Freequency')
plt.show()

# %%
df['50'].hist(bins=20,color = 'blue',edgecolor = 'black')
plt.title('50s')
plt.xlabel('Values')
plt.ylabel('Freequency')
plt.show()

# %%
df['0'].hist(bins=20,color = 'blue',edgecolor = 'black')
plt.title('0s')
plt.xlabel('Values')
plt.ylabel('Freequency')
plt.show()

# %%
df['Ave'].hist(bins=20,color = 'blue',edgecolor = 'black')
plt.title('Average')
plt.xlabel('Values')
plt.ylabel('Freequency')
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
correlation_matrix = df.iloc[:,2:6].corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
correlation_matrix = df.iloc[:,10:13].corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.scatterplot(x='Mat',y='Runs',data=df)
plt.title("Matches and Runs")
plt.show()

# %%
sns.scatterplot(x='Inns',y='Runs',data=df)
plt.title("Innings and Runs")
plt.show()

# %%
sns.scatterplot(x='Mat',y='100',data=df)
plt.title("Matches and 100s")
plt.show()

# %%
sns.scatterplot(x='Mat',y='50',data=df)
plt.title("Matches and 50s")
plt.show()

# %%
sns.scatterplot(x='Inns',y='100',data=df)
plt.title("Innings and 100s")
plt.show()

# %%
sns.scatterplot(x='Inns',y='50',data=df)
plt.title("Innings and 50s")
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
sns.pairplot(df,hue='Runs',diag_kind='kde')
plt.title('Pair plot')
plt.show()

# %%
fig = px.scatter_3d(df,x='Mat',y='Inns',z='Ave',color = 'Runs')
#fig.update(title='3d scatter plot')
fig.show()
# Out:
# <div>                            <div id="f86c9505-5f9f-4dca-8fe6-61012ea6bcf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f86c9505-5f9f-4dca-8fe6-61012ea6bcf1")) {                    Plotly.newPlot(                        "f86c9505-5f9f-4dca-8fe6-61012ea6bcf1",                        [{"hovertemplate":"Mat=%{x}\u003cbr\u003eInns=%{y}\u003cbr\u003eAve=%{z}\u003cbr\u003eRuns=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[6996,1181,1485,2256,2190,4555,1540,6806,4455,7249,9537,8032,12400,5410,3798,6971,13289,990,8263,1301,1084,7110,2960,15921,1452,11953,8832,13288,7530,10099,4007,13378,1394,4794,6235,11867,10122,10927,8625,8765,11174,11416,8540,5807,11814,8830,3860,1185,8586,1180,8848,8643,1669,3471,14
# ...

# %% [markdown]
# Data Cleaning
